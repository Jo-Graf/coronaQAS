# %%
from haystack.document_store.elasticsearch import ElasticsearchDocumentStore
from haystack.finder import Finder
from backend_app.qas_core.got_data_loader import GOTDataLoader
from haystack.retriever.sparse import ElasticsearchRetriever
from haystack.reader.farm import FARMReader
from haystack.reader.transformers import TransformersReader

# %%
data_loader = GOTDataLoader()
dicts = data_loader.load_data()
# Out:
# 3.6.3 (v3.6.3:2c5fed86e0, Oct  3 2017, 00:32:08)
# [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]
# sys.version_info(major=3, minor=6, micro=3, releaselevel='final', serial=0)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-32-71d1bac02f7d> in <module>
#       1 data_loader = GOTDataLoader()
# ----> 2 dicts = data_loader.load_data()
#
# ~/Belegarbeit/django_backend/backend_app/qas_core/got_data_loader.py in load_data(self)
#      31         # You can optionally supply a cleaning function that is applied to each doc (e.g. to remove footers)
#      32         # It must take a str as input, and return a str.
# ---> 33         dicts = convert_files_to_dicts(dir_path=doc_dir, clean_func=clean_wiki_text, split_paragraphs=True)
#      34
#      35         GOTDataLoader.data_is_loaded = True
#
# ~/PycharmProjects/python-virtual-environments/venv_3_6/lib/python3.6/site-packages/haystack/preprocessor/utils.py in convert_files_to_dicts(dir_path, clean_func, split_paragraphs)
#      96         if path.suffix.lower() == ".txt":
#      97             with open(path) as doc:
# ---> 98                 print('doc_path: ' + str(path))
#      99                 text = doc.read()
#     100         elif path.suffix.lower() == ".pdf" and pdf_converter:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/encodings/ascii.py in decode(self, input, final)
#      24 class IncrementalDecoder(codecs.IncrementalDecoder):
#      25     def decode(self, input, final=False):
# ---> 26         return codecs.ascii_decode(input, self.errors)[0]
#      27
#      28 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 29: ordinal not in range(128)

# %%
# Initialize
document_store = ElasticsearchDocumentStore(host="localhost", username="", password="", index="document")
data_loader = GOTDataLoader()
# Out:
# 10/04/2020 13:04:53 - INFO - elasticsearch -   HEAD http://localhost:9200/document [status:200 request:0.150s]
# 10/04/2020 13:04:53 - INFO - elasticsearch -   PUT http://localhost:9200/label [status:200 request:0.439s]

# %%
# load data
if not data_loader.data_is_loaded():
    dicts = data_loader.load_data()
    document_store.write_documents(dicts)

# %%
dicts = data_loader.load_data()
dicts
# Out:
# 3.6.3 (v3.6.3:2c5fed86e0, Oct  3 2017, 00:32:08)
# [GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]
# sys.version_info(major=3, minor=6, micro=3, releaselevel='final', serial=0)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-23-6a361f943906> in <module>
# ----> 1 dicts = data_loader.load_data()
#       2 dicts
#       3
#
# ~/Belegarbeit/django_backend/backend_app/qas_core/got_data_loader.py in load_data(self)
#      31         # You can optionally supply a cleaning function that is applied to each doc (e.g. to remove footers)
#      32         # It must take a str as input, and return a str.
# ---> 33         dicts = convert_files_to_dicts(dir_path=doc_dir, clean_func=clean_wiki_text, split_paragraphs=True)
#      34
#      35         GOTDataLoader.data_is_loaded = True
#
# ~/PycharmProjects/python-virtual-environments/venv_3_6/lib/python3.6/site-packages/haystack/preprocessor/utils.py in convert_files_to_dicts(dir_path, clean_func, split_paragraphs)
#      96         if path.suffix.lower() == ".txt":
#      97             with open(path) as doc:
# ---> 98                 text = doc.read()
#      99         elif path.suffix.lower() == ".pdf" and pdf_converter:
#     100             document = pdf_converter.convert(path)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/encodings/ascii.py in decode(self, input, final)
#      24 class IncrementalDecoder(codecs.IncrementalDecoder):
#      25     def decode(self, input, final=False):
# ---> 26         return codecs.ascii_decode(input, self.errors)[0]
#      27
#      28 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 29: ordinal not in range(128)

# %%
for d in dicts:
    print(d['meta'])
# Out:
# {'name': '145_Elio_M._García_Jr._and_Linda_Antonsson.txt'}
# {'name': '145_Elio_M._García_Jr._and_Linda_Antonsson.txt'}
# {'name': '145_Elio_M._García_Jr._and_Linda_Antonsson.txt'}
# {'name': '145_Elio_M._García_Jr._and_Linda_Antonsson.txt'}
# {'name': '326_Walder_Rivers.txt'}
# {'name': '312_Dickon_Tarly.txt'}
# {'name': '377_Kevan_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '368_Jaime_Lannister.txt'}
# {'name': '133_Game_of_Thrones__Season_5__soundtrack_.txt'}
# {'name': '133_Game_of_Thrones__Season_5__soundtrack_.txt'}
# {'name': '133_Game_of_Thrones__Season_5__soundtrack_.txt'}
# {'name': '133_Game_of_Thrones__Season_5__soundtrack_.txt'}
# {'name': '91_Pycelle.txt'}
# {'name': '185_Aegon_I_Targaryen.txt'}
# {'name': '170_Viserys_I_Targaryen.txt'}
# {'name': '412_Roslin_Tully.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '515_The_Door__Game_of_Thrones_.txt'}
# {'name': '322_Meryn_Trant.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '119_Walk_of_Punishment.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '369_Samwell_Tarly.txt'}
# {'name': '366_The_Art_of_George_R._R._Martin_s_A_Song_of_Ice_and_Fire.txt'}
# {'name': '81_Storm_s_End.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '356_Tales_of_Dunk_and_Egg.txt'}
# {'name': '65_Three-eyed_Raven.txt'}
# {'name': '459_Septon_Meribald.txt'}
# {'name': '164_Aerion_Targaryen.txt'}
# {'name': '318_Gerold_Hightower.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '195_World_of_A_Song_of_Ice_and_Fire.txt'}
# {'name': '113_Oldtown__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '375_Lyanna_Stark.txt'}
# {'name': '509_Osha__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '25_Game_of_Thrones__Season_2__soundtrack_.txt'}
# {'name': '25_Game_of_Thrones__Season_2__soundtrack_.txt'}
# {'name': '25_Game_of_Thrones__Season_2__soundtrack_.txt'}
# {'name': '25_Game_of_Thrones__Season_2__soundtrack_.txt'}
# {'name': '42_Robert_Arryn.txt'}
# {'name': '50_Aegon_VI_Targaryen.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '460_Battle_of_the_Bastards.txt'}
# {'name': '511_After_the_Thrones.txt'}
# {'name': '511_After_the_Thrones.txt'}
# {'name': '511_After_the_Thrones.txt'}
# {'name': '511_After_the_Thrones.txt'}
# {'name': '511_After_the_Thrones.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '69_The_Red_Woman.txt'}
# {'name': '137_Lord_Hoster_Tully.txt'}
# {'name': '36_Rhaegar_Targaryen.txt'}
# {'name': '352_Westeros.txt'}
# {'name': '167_Rhaenys_Targaryen__daughter_of_Rhaegar_.txt'}
# {'name': '237_Dorne.txt'}
# {'name': '250_Sybell_Westerling.txt'}
# {'name': '271_Westerlands.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '407_The_Long_Night__Game_of_Thrones_.txt'}
# {'name': '440_Free_Cities__ASOIAF_.txt'}
# {'name': '428_Aegon_Frey.txt'}
# {'name': '238_Braavos__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '297_Loreza_Sand.txt'}
# {'name': '296_Dorea_Sand.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '201_A_Game_of_Thrones__card_game_.txt'}
# {'name': '464_Doom_of_Valyria.txt'}
# {'name': '226_Greyjoy.txt'}
# {'name': '128_Ned_Stark_s_Bastard.txt'}
# {'name': '82_Stormlands.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '97_Tyrion_Lannister.txt'}
# {'name': '242_Norvos.txt'}
# {'name': '219_Elia_Targaryen.txt'}
# {'name': '259_Qhorin_Halfhand.txt'}
# {'name': '401_Power_Is_Power.txt'}
# {'name': '401_Power_Is_Power.txt'}
# {'name': '401_Power_Is_Power.txt'}
# {'name': '401_Power_Is_Power.txt'}
# {'name': '401_Power_Is_Power.txt'}
# {'name': '401_Power_Is_Power.txt'}
# {'name': '497_Areo_Hotah.txt'}
# {'name': '51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '190_Targaryen.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '20_Light_of_the_Seven.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '359_Kill_the_Boy.txt'}
# {'name': '165_Baelor_Targaryen.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '224_The_Night_Lands.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '8_Eastwatch.txt'}
# {'name': '462_3_eyed_raven.txt'}
# {'name': '505_Robert_the_Usurper.txt'}
# {'name': '406_Dragonstone__Game_of_Thrones_location_.txt'}
# {'name': '391_Daemon_Blackfyre.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '11_The_Dragon_and_the_Wolf.txt'}
# {'name': '112_Harrold_Hardyng.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '53_The_Lion_and_the_Rose.txt'}
# {'name': '303_Maekar_Targaryen.txt'}
# {'name': '503_Melessa_Tarly.txt'}
# {'name': '136_Game_of_Thrones__Season_8__soundtrack_.txt'}
# {'name': '136_Game_of_Thrones__Season_8__soundtrack_.txt'}
# {'name': '136_Game_of_Thrones__Season_8__soundtrack_.txt'}
# {'name': '136_Game_of_Thrones__Season_8__soundtrack_.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '439_Melisandre.txt'}
# {'name': '457_Wyman_Manderly.txt'}
# {'name': '248_Trystane_Martell.txt'}
# {'name': '325_Anya_Waynwood.txt'}
# {'name': '419_Brandon_I_Stark.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '485_Oathkeeper.txt'}
# {'name': '26_Game_of_Thrones__Season_3__soundtrack_.txt'}
# {'name': '26_Game_of_Thrones__Season_3__soundtrack_.txt'}
# {'name': '26_Game_of_Thrones__Season_3__soundtrack_.txt'}
# {'name': '26_Game_of_Thrones__Season_3__soundtrack_.txt'}
# {'name': '26_Game_of_Thrones__Season_3__soundtrack_.txt'}
# {'name': '243_Selyse_Florent.txt'}
# {'name': '63_Brynden_Rivers.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '329_Robert_Baratheon.txt'}
# {'name': '35_The_Eyrie.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '443_The_Kingsroad.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '198_A_Clash_of_Kings.txt'}
# {'name': '146_The_Sons_of_the_Dragon.txt'}
# {'name': '146_The_Sons_of_the_Dragon.txt'}
# {'name': '146_The_Sons_of_the_Dragon.txt'}
# {'name': '146_The_Sons_of_the_Dragon.txt'}
# {'name': '146_The_Sons_of_the_Dragon.txt'}
# {'name': '107_Yunkai.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '68_The_Gift__Game_of_Thrones_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '311_Game_of_Thrones__season_7_.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '482_Petyr_Baelish.txt'}
# {'name': '17_The_Eyrie__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '393_Dragonstone__castle_.txt'}
# {'name': '108_Asshai.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '7_The_Spoils_of_War__Game_of_Thrones_.txt'}
# {'name': '405_Beyond_the_Wall__Game_of_Thrones_location_.txt'}
# {'name': '104_Aemon.txt'}
# {'name': '162_Howland_Reed.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '332_Sansa_Stark.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '30_List_of_A_Song_of_Ice_and_Fire_characters.txt'}
# {'name': '301_Lollys_Stokeworth.txt'}
# {'name': '286_The_Unsullied.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '55_Breaker_of_Chains.txt'}
# {'name': '175_Helaena_Targaryen.txt'}
# {'name': '339_House_Tyrell.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '342_Theon_Greyjoy.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '197_A_Game_of_Thrones.txt'}
# {'name': '52_Catch_the_Throne.txt'}
# {'name': '52_Catch_the_Throne.txt'}
# {'name': '52_Catch_the_Throne.txt'}
# {'name': '52_Catch_the_Throne.txt'}
# {'name': '52_Catch_the_Throne.txt'}
# {'name': '41_Lysa_Arryn.txt'}
# {'name': '169_Alicent_Hightower.txt'}
# {'name': '468_Aemon_Targaryen.txt'}
# {'name': '176_Aemond_Targaryen.txt'}
# {'name': '293_Sarella_Sand.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '194_A_Song_of_Ice_and_Fire.txt'}
# {'name': '95_Jeyne_Poole.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '273_High_Sparrow.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '454_Music_of_Game_of_Thrones.txt'}
# {'name': '294_Elia_Sand.txt'}
# {'name': '475_A_Game_of_Thrones__role-playing_game_.txt'}
# {'name': '475_A_Game_of_Thrones__role-playing_game_.txt'}
# {'name': '475_A_Game_of_Thrones__role-playing_game_.txt'}
# {'name': '475_A_Game_of_Thrones__role-playing_game_.txt'}
# {'name': '475_A_Game_of_Thrones__role-playing_game_.txt'}
# {'name': '475_A_Game_of_Thrones__role-playing_game_.txt'}
# {'name': '161_Aeron_Greyjoy.txt'}
# {'name': '285_Slaver_s_Bay.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '446_A_Golden_Crown.txt'}
# {'name': '153_Mace_Tyrell.txt'}
# {'name': '92_Ilyn_Payne.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '360_List_of_Game_of_Thrones_episodes.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '207_Jon_Snow__character_.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '44_Daenerys_Targaryen.txt'}
# {'name': '160_Viserys_Targaryen.txt'}
# {'name': '160_Viserys_Targaryen.txt'}
# {'name': '160_Viserys_Targaryen.txt'}
# {'name': '160_Viserys_Targaryen.txt'}
# {'name': '160_Viserys_Targaryen.txt'}
# {'name': '160_Viserys_Targaryen.txt'}
# {'name': '160_Viserys_Targaryen.txt'}
# {'name': '109_Meereen.txt'}
# {'name': '307_Ser_Alliser.txt'}
# {'name': '241_R_hllor.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '395_Game_of_Thrones__season_5_.txt'}
# {'name': '431_Emmon_Frey.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '78_The_Rains_of_Castamere.txt'}
# {'name': '99_A_Song_of_Ass_and_Fire.txt'}
# {'name': '99_A_Song_of_Ass_and_Fire.txt'}
# {'name': '99_A_Song_of_Ass_and_Fire.txt'}
# {'name': '99_A_Song_of_Ass_and_Fire.txt'}
# {'name': '99_A_Song_of_Ass_and_Fire.txt'}
# {'name': '392_Pyke__castle_.txt'}
# {'name': '18_Winterfell__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '411_The_Iron_Throne__Game_of_Thrones_.txt'}
# {'name': '321_Lothar_Frey.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '74_The_Prince_of_Winterfell.txt'}
# {'name': '389_Daemon_II_Blackfyre.txt'}
# {'name': '463_Izembaro.txt'}
# {'name': '486_Ronnet_Connington.txt'}
# {'name': '14_Pyke__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '324_Rodrik_Cassel.txt'}
# {'name': '421_Wylis.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '233_Myrcella_Baratheon.txt'}
# {'name': '189_War_of_the_Ninepenny_Kings.txt'}
# {'name': '516_Myranda.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '445_The_Wolf_and_the_Lion.txt'}
# {'name': '354_Vale_of_Arryn.txt'}
# {'name': '272_Volantis__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '77_Game_of_Thrones_Ascent.txt'}
# {'name': '77_Game_of_Thrones_Ascent.txt'}
# {'name': '77_Game_of_Thrones_Ascent.txt'}
# {'name': '77_Game_of_Thrones_Ascent.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '420_Blood_of_My_Blood.txt'}
# {'name': '275_Bowen_Marsh.txt'}
# {'name': '472_Vhagar.txt'}
# {'name': '148_Game_of_Thrones__Winter_Is_Coming.txt'}
# {'name': '148_Game_of_Thrones__Winter_Is_Coming.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '39_Renly_Baratheon.txt'}
# {'name': '115_Iron_Islands.txt'}
# {'name': '490_Braavos.txt'}
# {'name': '22_The_Rains_of_Castamere__song_.txt'}
# {'name': '22_The_Rains_of_Castamere__song_.txt'}
# {'name': '22_The_Rains_of_Castamere__song_.txt'}
# {'name': '22_The_Rains_of_Castamere__song_.txt'}
# {'name': '22_The_Rains_of_Castamere__song_.txt'}
# {'name': '83_Riverlands__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '49_A_Feast_for_Crows__board_game_.txt'}
# {'name': '152_Hoster_Tully.txt'}
# {'name': '236_Pentos__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '249_Jeyne_Westerling.txt'}
# {'name': '156_Loras_Tyrell.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '9_Game_of_Thrones_Tapestry.txt'}
# {'name': '172_Daemon_Targaryen.txt'}
# {'name': '345_A_Game_of_Thrones__comics_.txt'}
# {'name': '345_A_Game_of_Thrones__comics_.txt'}
# {'name': '345_A_Game_of_Thrones__comics_.txt'}
# {'name': '345_A_Game_of_Thrones__comics_.txt'}
# {'name': '345_A_Game_of_Thrones__comics_.txt'}
# {'name': '345_A_Game_of_Thrones__comics_.txt'}
# {'name': '123_Red_Waste.txt'}
# {'name': '144_Varamyr_Sixskins.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '424_Night_King.txt'}
# {'name': '323_Othell_Yarwyck.txt'}
# {'name': '100_Castle_Black.txt'}
# {'name': '159_Victarion_Greyjoy.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '435_White_Walker.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '304_Hardhome.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# {'name': '12_Fire.txt'}
# ...
# {'name': '59_Eddison_Tollett.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '442_Game_of_Thrones__season_1_.txt'}
# {'name': '234_Doran_Martell.txt'}
# {'name': '149_Jon_Arryn.txt'}
# {'name': '174_Aegon_II_Targaryen.txt'}
# {'name': '192_Hot_Pie.txt'}
# {'name': '344_Ser_Duncan_the_Tall.txt'}
# {'name': '258_Yoren.txt'}
# {'name': '418_Elder_Brother__character_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '410_The_Bells__Game_of_Thrones_.txt'}
# {'name': '220_Aegon_V_Targaryen.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '213_Valyrian_languages.txt'}
# {'name': '64_Talisa_Stark.txt'}
# {'name': '507_The_Stormlands__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '126_Kissed_by_Fire.txt'}
# {'name': '264_Red_Wedding__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '212_The_Children__Game_of_Thrones_.txt'}
# {'name': '299_Rani_Mahal__TV_series_.txt'}
# {'name': '299_Rani_Mahal__TV_series_.txt'}
# {'name': '181_Lannister.txt'}
# {'name': '179_The_Red_Wedding.txt'}
# {'name': '32_Narrow_Sea.txt'}
# {'name': '467_Rast__character_.txt'}
# {'name': '314_Pypar.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '214_Dothraki_language.txt'}
# {'name': '506_Game_of_Thrones_Theme.txt'}
# {'name': '506_Game_of_Thrones_Theme.txt'}
# {'name': '506_Game_of_Thrones_Theme.txt'}
# {'name': '506_Game_of_Thrones_Theme.txt'}
# {'name': '506_Game_of_Thrones_Theme.txt'}
# {'name': '506_Game_of_Thrones_Theme.txt'}
# {'name': '506_Game_of_Thrones_Theme.txt'}
# {'name': '315_Grenn.txt'}
# {'name': '221_Maekar_I_Targaryen.txt'}
# {'name': '245_The_Seven__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '492_The_Dothraki_Sea.txt'}
# {'name': '235_Quentyn_Martell.txt'}
# {'name': '244_Selyse_Baratheon.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '367_Gregor_Clegane.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '151_Ellaria_Sand.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '191_Gendry.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '79_Thronecast.txt'}
# {'name': '289_Edric_Storm.txt'}
# {'name': '206_Winterfell.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '477_A_Dance_with_Dragons.txt'}
# {'name': '470_Casterly_Rock__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '193_Lord_Snow.txt'}
# {'name': '382_Aegon_III_Targaryen.txt'}
# {'name': '223_Rhaella_Targaryen.txt'}
# {'name': '429_House_Frey.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '514_Book_of_the_Stranger.txt'}
# {'name': '380_Asha_Greyjoy.txt'}
# {'name': '448_Night_s_Watch.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '334_Rickon_Stark.txt'}
# {'name': '186_Aegon_I.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '210_The_Mountain_and_the_Viper.txt'}
# {'name': '438_Across_the_narrow_sea.txt'}
# {'name': '103_Maester_Aemon.txt'}
# {'name': '140_Clegane.txt'}
# {'name': '178_Jaehaerys_Targaryen__son_of_Aegon_II_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '127_The_Climb__Game_of_Thrones_.txt'}
# {'name': '38_Edmure_Tully.txt'}
# {'name': '184_The_War_of_the_Usurper.txt'}
# {'name': '62_Bronze_Yohn.txt'}
# {'name': '256_Valyrian_steel.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '3_The_Queen_s_Justice.txt'}
# {'name': '403_Jenny_of_Oldstones.txt'}
# {'name': '403_Jenny_of_Oldstones.txt'}
# {'name': '403_Jenny_of_Oldstones.txt'}
# {'name': '403_Jenny_of_Oldstones.txt'}
# {'name': '403_Jenny_of_Oldstones.txt'}
# {'name': '403_Jenny_of_Oldstones.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '129_Second_Sons.txt'}
# {'name': '138_Wun_Wun.txt'}
# {'name': '204_House_Lannister.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '349_List_of_Game_of_Thrones_characters.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '118_Dark_Wings__Dark_Words.txt'}
# {'name': '16_Sunspear__A_Song_of_Ice_and_Fire_.txt'}
# {'name': '200_House_Stark.txt'}
# {'name': '493_Syrio_Forel.txt'}
# {'name': '358_A_Game_of_Thrones__Genesis.txt'}
# {'name': '358_A_Game_of_Thrones__Genesis.txt'}
# {'name': '358_A_Game_of_Thrones__Genesis.txt'}
# {'name': '358_A_Game_of_Thrones__Genesis.txt'}
# {'name': '298_Greyworm.txt'}
# {'name': '489_Illyrio_Mopatis.txt'}
# {'name': '284_Wildlings.txt'}
# {'name': '465_Robert_s_Rebellion.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '2_Stormborn.txt'}
# {'name': '182_War_of_the_Usurper.txt'}
# {'name': '274_Yezzan.txt'}

# %%
# initialize retriever
retriever = ElasticsearchRetriever(document_store=document_store)

# %%
# initialize reader
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=False)
# Out:
# 10/04/2020 13:05:13 - INFO - farm.utils -   device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# 10/04/2020 13:05:13 - INFO - farm.infer -   Could not find `deepset/roberta-base-squad2` locally. Try to download from model hub ...
# 10/04/2020 13:05:19 - WARNING - farm.modeling.language_model -   Could not automatically detect from language model name what language it is.
# 	 We guess it's an *ENGLISH* model ...
# 	 If not: Init the language model by supplying the 'language' param.
# 10/04/2020 13:05:24 - WARNING - farm.modeling.prediction_head -   Some unused parameters are passed to the QuestionAnsweringHead. Might not be a problem. Params: {"loss_ignore_index": -1}
# 10/04/2020 13:05:28 - INFO - farm.utils -   device: cpu n_gpu: 0, distributed training: False, automatic mixed precision training: None
# 10/04/2020 13:05:28 - INFO - farm.infer -   Got ya 7 parallel workers to do inference ...
# 10/04/2020 13:05:28 - INFO - farm.infer -    0    0    0    0    0    0    0
# 10/04/2020 13:05:28 - INFO - farm.infer -   /w\  /w\  /w\  /w\  /w\  /w\  /w\
# 10/04/2020 13:05:28 - INFO - farm.infer -   /'\  / \  /'\  /'\  / \  / \  /'\
# 10/04/2020 13:05:28 - INFO - farm.infer -

# %%
# initialize finder
finder = Finder(reader, retriever)

# %%
# predict
prediction = finder.get_answers(question="Who is the red witch?", top_k_retriever=20, top_k_reader=10)
# Out:
# 10/04/2020 13:05:28 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.385s]
# 10/04/2020 13:05:28 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/04/2020 13:05:28 - INFO - haystack.finder -   Reader is looking for detailed answer in 49920 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:02<00:00,  2.01s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.11s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.11s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.15s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.12s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.09s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.07s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.08s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.10s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.16s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.09s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.10s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.13s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.10s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.22s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.11s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.21s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.12s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.11s/ Batches]
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.16s/ Batches]

# %%
# print answers
# print_answers(prediction, details="all")
# Out:
# {   'answers': [   {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': '-ixA4nMBreXvbNGuGruj',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': '9Sxw4nMBreXvbNGulcZY',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': 'EywL4nMBreXvbNGu6YWD',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': 'Diwb4nMBreXvbNGu85DF',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': '8Cx54nMBreXvbNGuw9Es',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': '_yw_4nMBreXvbNGuNrAN',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': 'BCw04nMBreXvbNGuCaZQ',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': 'CSww4nMBreXvbNGuhJsa',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': '9GIOG3QB7VlRhbqQXQDW',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959},
#                    {   'answer': 'Melisandre',
#                        'context': 'er Jon Snow would remain dead or return to '
#                                   'life. Fans speculated that Melisandre would '
#                                   'be the one to bring back Snow to life, '
#                                   'after and before the tit',
#                        'document_id': '6ywy53MBreXvbNGuwtyZ',
#                        'meta': {'name': '69_The_Red_Woman.txt'},
#                        'offset_end': 80,
#                        'offset_end_in_doc': 1063,
#                        'offset_start': 70,
#                        'offset_start_in_doc': 1053,
#                        'probability': 0.5248341338350121,
#                        'score': 0.795346736907959}],
#     'no_ans_gap': -9.534895420074463,
#     'question': 'Who is the red witch?'}

# %%
prediction
# Out:
# {'question': 'Who is the red witch?',
#  'no_ans_gap': -9.534895420074463,
#  'answers': [{'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': '-ixA4nMBreXvbNGuGruj',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': '9Sxw4nMBreXvbNGulcZY',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': 'EywL4nMBreXvbNGu6YWD',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': 'Diwb4nMBreXvbNGu85DF',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': '8Cx54nMBreXvbNGuw9Es',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': '_yw_4nMBreXvbNGuNrAN',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': 'BCw04nMBreXvbNGuCaZQ',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': 'CSww4nMBreXvbNGuhJsa',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': '9GIOG3QB7VlRhbqQXQDW',
#    'meta': {'name': '69_The_Red_Woman.txt'}},
#   {'answer': 'Melisandre',
#    'score': 0.795346736907959,
#    'probability': 0.5248341338350121,
#    'context': 'er Jon Snow would remain dead or return to life. Fans speculated that Melisandre would be the one to bring back Snow to life, after and before the tit',
#    'offset_start': 70,
#    'offset_end': 80,
#    'offset_start_in_doc': 1053,
#    'offset_end_in_doc': 1063,
#    'document_id': '6ywy53MBreXvbNGuwtyZ',
#    'meta': {'name': '69_The_Red_Woman.txt'}}]}
